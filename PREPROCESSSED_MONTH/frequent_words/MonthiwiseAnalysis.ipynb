# %%
import pandas as pd
import numpy as np
from textblob import TextBlob as tb
from textblob import Word
from nltk.corpus import stopwords
import neattext.functions as nfx
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
from wordcloud import WordCloud
from PIL import Image
plt.style.use('ggplot')
import string
from string import digits

from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

import warnings
warnings.simplefilter('ignore')

# %%
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use', 'not', 'would', 'say', 'could', '_', 'be', 'know', 'good', 'go', 'get', 'do', 'done', 'try', 'many', 'some', 'nice', 'thank', 'think', 'see', 'rather', 'easy', 'easily', 'lot', 'lack', 'make', 'want', 'seem', 'run', 'need', 'even', 'right', 'line', 'even', 'also', 'may', 'take', 'come','%','.','the','etc','pls','btw','let','hgd'])

# %%
march=pd.read_csv('01_PREPROCESSED_MARCH.csv')
april=pd.read_csv('02_PREPROCESSED_APRIL.csv')
may=pd.read_csv('03_PREPROCESSED_MAY.csv')
june=pd.read_csv('04_PREPROCESSED_JUNE.csv')
july=pd.read_csv('05_PREPROCESSED_JULY.csv')
august=pd.read_csv('06_PREPROCESSED_AUGUST.csv')

# %%
custom_words = ['from', 'subject', 're', 'edu', 'use', 'not', 'would', 'say', 'could', '_', 'be', 'know', 'good', 'go', 'get', 'do', 'done', 'try', 'many', 'some', 'nice', 'thank', 'think', 'see', 'rather',
                'easy', 'easily', 'lot', 'lack', 'make', 'want', 'seem', 'run', 'need', 'even', 'right', 'line', 'even', 'also', 'may', 'take', 'come', '%', '.', 'the', 'etc', 'pls', 'btw', 'let', 'hgd', 'get', 'amp', 'gt','lt']

# %%
for i in range(0,2452):
    march['clean_tweet'][i]= ''.join([i for i in march['clean_tweet'][i] if not i.isdigit()])
    march['clean_tweet'][i]=march['clean_tweet'][i].lower()
    march['clean_tweet'][i]=nfx.remove_custom_words(march['clean_tweet'][i],custom_words)
for i in range(0,2624):
    april['clean_tweet'][i]= ''.join([i for i in april['clean_tweet'][i] if not i.isdigit()])
    april['clean_tweet'][i]=april['clean_tweet'][i].lower()
    april['clean_tweet'][i]=nfx.remove_custom_words(april['clean_tweet'][i],custom_words)
for i in range(0,1836):
    may['clean_tweet'][i]= ''.join([i for i in may['clean_tweet'][i] if not i.isdigit()])
    may['clean_tweet'][i]=may['clean_tweet'][i].lower()
    may['clean_tweet'][i]=nfx.remove_custom_words(may['clean_tweet'][i],custom_words)
for i in range(0,2439):
    june['clean_tweet'][i]= ''.join([i for i in june['clean_tweet'][i] if not i.isdigit()])
    june['clean_tweet'][i]=june['clean_tweet'][i].lower()
    june['clean_tweet'][i]=nfx.remove_custom_words(june['clean_tweet'][i],custom_words)
for i in range(0,1993):
    july['clean_tweet'][i]= ''.join([i for i in july['clean_tweet'][i] if not i.isdigit()])
    july['clean_tweet'][i]=july['clean_tweet'][i].lower()
    july['clean_tweet'][i]=nfx.remove_custom_words(july['clean_tweet'][i],custom_words)
for i in range(0,1698):
    august['clean_tweet'][i]= ''.join([i for i in august['clean_tweet'][i] if not i.isdigit()])
    august['clean_tweet'][i]=august['clean_tweet'][i].lower()
    august['clean_tweet'][i]=nfx.remove_custom_words(august['clean_tweet'][i],custom_words)

# %%
march['tokenized_Tweet']=np.nan
april['tokenized_Tweet']=np.nan
may['tokenized_Tweet']=np.nan
june['tokenized_Tweet']=np.nan
july['tokenized_Tweet']=np.nan
august['tokenized_Tweet']=np.nan

# %%
def tokenizing_march(text,i=0):
    text=tb(text)
    token_text=text.words
    token_text
    march['tokenized_Tweet'][i]=token_text
def tokenizing_april(text,i=0):
    text=tb(text)
    token_text=text.words
    token_text
    april['tokenized_Tweet'][i]=token_text
def tokenizing_may(text,i=0):
    text=tb(text)
    token_text=text.words
    token_text
    may['tokenized_Tweet'][i]=token_text
def tokenizing_june(text,i=0):
    text=tb(text)
    token_text=text.words
    token_text
    june['tokenized_Tweet'][i]=token_text
def tokenizing_july(text,i=0):
    text=tb(text)
    token_text=text.words
    token_text
    july['tokenized_Tweet'][i]=token_text
def tokenizing_august(text,i=0):
    text=tb(text)
    token_text=text.words
    token_text
    august['tokenized_Tweet'][i]=token_text

# %%
tokenizing_march(march['clean_tweet'][0],0)

# %%
a=march.shape
b=april.shape
c=may.shape
d=june.shape
e=july.shape
f=august.shape
print(a,b,c,d,e,f)
# Out:
# (2452, 7) (2624, 7) (1836, 7) (2439, 7) (1993, 7) (1698, 7)

# %%
for i in range(0,2452):
    text=march['clean_tweet'][i]
    tokenizing_march(text,i)

# %%
for i in range(0,2624):
    text=april['clean_tweet'][i]
    tokenizing_april(text,i)

# %%
for i in range(0,1836):
    text=may['clean_tweet'][i]
    tokenizing_may(text,i)

# %%
for i in range(0,2439):
    text=june['clean_tweet'][i]
    tokenizing_june(text,i)

# %%
for i in range(0,1993):
    text=july['clean_tweet'][i]
    tokenizing_july(text,i)

# %%
for i in range(0,1698):
    text=august['clean_tweet'][i]
    tokenizing_august(text,i)

# %%
august
# Out:
#                                                   tweet  \
# 0     Line of Treatment for Covid-19 Hydroquinone  I...
# 1     Yes, it's Oxygen and Remdesivir Versus Hindu-M...
# 2     @KDMCOfficial one of my pts needs remdesivir a...
# 3     So many citizens across India requested you fo...
# 4     Remdesivir “made in India” just reached #HoChi...
# ...                                                 ...
# 1693  I thought things would go back to normal by th...
# 1694    𝓣𝓸 𝓽𝓪𝓴𝓮 𝓸𝓻 𝓷𝓸𝓽 𝓽𝓸 𝓽𝓪𝓴𝓮 - the Covid  - 19 vac...
# 1695  US Top COVID-19 Advisor Says No New Lockdowns ...
# 1696  "How COVID-19 vaccines are being prioritized a...
# 1697  Updated schedule announced by \n@ICC\n , as \n...
#
#                                             clean_tweet  \
# 0     of treatment for covid hydroquinone ivermectin...
# 1     yes its oxygen and remdesivir versus hindumusl...
# 2     one of my pts needs remdesivir and tociluzimab...
# 3     so citizens across india requested you for oxy...
# ...

# %%
march['filteredToken']=np.nan
april['filteredToken']=np.nan
may['filteredToken']=np.nan
june['filteredToken']=np.nan
july['filteredToken']=np.nan
august['filteredToken']=np.nan

# %%
text_set=set(march['tokenized_Tweet'][0])
stop_set=set(stopwords.words("english"))
march['filteredToken'][0]=list(text_set-stop_set)

# %%
march.shape[0]
# Out:
# 2452

# %%
stop = set(stop_words)
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()

def clean(text):
    stop_free = ' '.join([word for word in text.lower().split() if word not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = ' '.join([lemma.lemmatize(word) for word in punc_free.split()])
    return normalized.split()

# %%
march['filteredToken']=march['clean_tweet'].apply(clean)
april['filteredToken']=april['clean_tweet'].apply(clean)
may['filteredToken']=may['clean_tweet'].apply(clean)
june['filteredToken']=june['clean_tweet'].apply(clean)
july['filteredToken']=july['clean_tweet'].apply(clean)
august['filteredToken']=august['clean_tweet'].apply(clean)

# %%
tweets_march=march['clean_tweet']
tweets_april=april['clean_tweet']
tweets_may=may['clean_tweet']
tweets_june=june['clean_tweet']
tweets_july=july['clean_tweet']
tweets_august=august['clean_tweet']

# %%
tweet_list_march = tweets_march.apply(nfx.remove_stopwords)
tweet_list_march = tweet_list_march .apply(nfx.remove_special_characters)
tweet_list_march = tweet_list_march.apply(nfx.remove_punctuations)
# tweets_tokens_march= [token for line in tweet_list_march for token in line.split()]

tweet_list_april = tweets_april.apply(nfx.remove_stopwords)
tweet_list_april =tweet_list_april .apply(nfx.remove_special_characters)
tweet_list_april = tweet_list_april.apply(nfx.remove_punctuations)
# tweets_tokens_april= [token for line in tweet_list_april for token in line.split()]

tweet_list_may = tweets_may.apply(nfx.remove_stopwords)
tweet_list_may = tweet_list_may .apply(nfx.remove_special_characters)
tweet_list_may = tweet_list_may.apply(nfx.remove_punctuations)
# tweets_tokens_may= [token for line in tweet_list_may for token in line.split()]

tweet_list_june = tweets_june.apply(nfx.remove_stopwords)
tweet_list_june = tweet_list_june.apply(nfx.remove_special_characters)
tweet_list_june = tweet_list_june.apply(nfx.remove_punctuations)
# tweets_tokens_june= [token for line in tweet_list_june for token in line.split()]

tweet_list_july = tweets_july.apply(nfx.remove_stopwords)
tweet_list_july = tweet_list_july .apply(nfx.remove_special_characters)
tweet_list_july =tweet_list_july.apply(nfx.remove_punctuations)
# tweets_tokens_july= [token for line in tweet_list_july for token in line.split()]

tweet_list_august = tweets_august.apply(nfx.remove_stopwords)
tweet_list_august = tweet_list_august.apply(nfx.remove_special_characters)
tweet_list_august =tweet_list_august.apply(nfx.remove_punctuations)
# tweets_tokens_august= [token for line in tweet_list_august for token in line.split()]

# %%
def remove_single_char(list):
    for token in list:
        if( len(token)==1):
            list.remove(token)
def remove_dual_char(list):
    for token in list:
        if( len(token)==2):
            list.remove(token)
def remove_words(list1, remove_words):
    for word in list(list1):
        if word in remove_words:
            list1.remove(word)
    return list1

# %%
custom_words = ['from', 'subject', 're', 'edu', 'use', 'not', 'would', 'say', 'could', '_', 'be', 'know', 'good', 'go', 'get', 'do', 'done', 'try', 'many', 'some', 'nice', 'thank', 'think', 'see', 'rather',
                'easy', 'easily', 'lot', 'lack', 'make', 'want', 'seem', 'run', 'need', 'even', 'right', 'line', 'even', 'also', 'may', 'take', 'come', '%', '.', 'the', 'etc', 'pls', 'btw', 'let', 'hgd', 'get', 'amp', 'gt','lt','hrs','dos','say']

# %%
def Convert_list(string):
    li = list(string.split(" "))
    return li
def listToString(s): 
    str1 = " " 
    return (str1.join(s))

# %%
a=march.shape
b=april.shape
c=may.shape
d=june.shape
e=july.shape
f=august.shape
print(a,b,c,d,e,f)
# Out:
# (2452, 8) (2624, 8) (1836, 8) (2439, 8) (1993, 8) (1698, 8)

# %%
for i in range(0,2452):
    ls=Convert_list(tweet_list_march[i])
    remove_single_char(ls)
    remove_dual_char(ls)
    ls=remove_words(ls,custom_words)
    tweet_list_march[i]=listToString(ls)
for i in range(0,2624):
    ls=Convert_list(tweet_list_april[i])
    remove_single_char(ls)
    remove_dual_char(ls)
    ls=remove_words(ls,custom_words)
    tweet_list_april[i]=listToString(ls)
for i in range(0,1836):
    ls=Convert_list(tweet_list_may[i])
    remove_single_char(ls)
    remove_dual_char(ls)
    ls=remove_words(ls,custom_words)
    tweet_list_may[i]=listToString(ls)
for i in range(0,2439):
    ls=Convert_list(tweet_list_june[i])
    remove_single_char(ls)
    remove_dual_char(ls)
    ls=remove_words(ls,custom_words)
    tweet_list_june[i]=listToString(ls)
for i in range(0,1993):
    ls=Convert_list(tweet_list_july[i])
    remove_single_char(ls)
    remove_dual_char(ls)
    ls=remove_words(ls,custom_words)
    tweet_list_july[i]=listToString(ls)
for i in range(0,1698):
    ls=Convert_list(tweet_list_august[i])
    remove_single_char(ls)
    remove_dual_char(ls)
    ls=remove_words(ls,custom_words)
    tweet_list_august[i]=listToString(ls)

# %%
def my_lemma(token,i=0):
    word=tb(token)
    tags=word.tags
    sample=Word(tags[0][0])
    if tags[0][1][0] =='V':
        x=sample.lemmatize('v')
        ls[i]=x
    else:
        x=sample.lemmatize()
        ls[i]=x

# %%
for i in range(0,2452):
    ls=Convert_list(tweet_list_march[i])
    for j in range(0,len(ls)):
        text=ls[j]
        if(text==""):
            continue
        my_lemma(text,j)
    tweet_list_march[i]=listToString(ls)
for i in range(0,2624):
    ls=Convert_list(tweet_list_april[i])
    for j in range(0,len(ls)):
        text=ls[j]
        if(text==""):
            continue
        my_lemma(text,j)
    tweet_list_april[i]=listToString(ls)
for i in range(0,1836):
    ls=Convert_list(tweet_list_may[i])
    for j in range(0,len(ls)):
        text=ls[j]
        if(text==""):
            continue
        my_lemma(text,j)
    tweet_list_may[i]=listToString(ls)
for i in range(0,2439):
    ls=Convert_list(tweet_list_june[i])
    for j in range(0,len(ls)):
        text=ls[j]
        if(text==""):
            continue
        my_lemma(text,j)
    tweet_list_june[i]=listToString(ls)
for i in range(0,1993):
    ls=Convert_list(tweet_list_july[i])
    for j in range(0,len(ls)):
        text=ls[j]
        if(text==""):
            continue
        my_lemma(text,j)
    tweet_list_july[i]=listToString(ls)
for i in range(0,1698):
    ls=Convert_list(tweet_list_august[i])
    for j in range(0,len(ls)):
        text=ls[j]
        if(text==""):
            continue
        my_lemma(text,j)
    tweet_list_august[i]=listToString(ls)

# %%
for i in range(0,2452):
    ls=Convert_list(tweet_list_march[i])
    ls=remove_words(ls,custom_words)
    tweet_list_march[i]=listToString(ls)
for i in range(0,2624):
    ls=Convert_list(tweet_list_april[i])
    ls=remove_words(ls,custom_words)
    tweet_list_april[i]=listToString(ls)
for i in range(0,1836):
    ls=Convert_list(tweet_list_may[i])
    ls=remove_words(ls,custom_words)
    tweet_list_may[i]=listToString(ls)
for i in range(0,2439):
    ls=Convert_list(tweet_list_june[i])
    ls=remove_words(ls,custom_words)
    tweet_list_june[i]=listToString(ls)
for i in range(0,1993):
    ls=Convert_list(tweet_list_july[i])
    ls=remove_words(ls,custom_words)
    tweet_list_july[i]=listToString(ls)
for i in range(0,1698):
    ls=Convert_list(tweet_list_august[i])
    ls=remove_words(ls,custom_words)
    tweet_list_august[i]=listToString(ls)

# %%
ps=PorterStemmer()

# %%
for i in range(0,august.shape[0]):
    ls=august['clean_tweet'][i]
    words = word_tokenize(ls)
    st=""
    for w in words:
        w=ps.stem(w)
        st+=w+' '
    august['clean_tweet'][i]=st

# %%
tweet_list_march
# Out:
# 0       germany covid response envy world daily remind...
# 1       pfizer moderna claim vaccine safe effective es...
# 2       recently publish predictor hospitalization old...
# 3        dey covid test aed private clinic govt free stop
# 4       time tell far base data million people vaccina...
#                               ...
# 2447    guy control covid state coronarastra maharastr...
# 2448    barasat hospital covid vaccine give people sit...
# 2449                                                reply
# 2450    dear sir request allow vaccination covid patie...
# 2451    dear sir request allow vaccination covid patie...
# Name: clean_tweet, Length: 2452, dtype: object

# %%
tweet_list_april
# Out:
# 0       covid infection lead clousure jamshedpur schoo...
# 1       uk glastonbury festival cinema museum governme...
# 2       covid lockdown desperate watch leak cum like t...
# 3       thanks orla pandemic tougher si canada hubster...
# 4       strict action dp ampc premier campus faisalaba...
#                               ...
# 2619                            bad time shopping despite
# 2620    request warrior movement help needy people pan...
# 2621    covid pandemic corona patient city like jaipur...
# 2622    covid news corona infection increase kumbh mel...
# 2623                                                reply
# Name: clean_tweet, Length: 2624, dtype: object

# %%
tweet_list_may
# Out:
# 0       corona virus possible rna mutation world far p...
# 1       second wave coronavirus infection india new va...
# 2       bbc news india coronavirus new record death vi...
# 3        wear mask sanitize hand maintain social distance
# 4       bbc news india coronavirus new record death vi...
#                               ...
# 1831    great gesture bhaiya people like help situatio...
# 1832    check vacant bed availability online hospital ...
# 1833    fight war covid vaccine vaccine ample quantity...
# 1834                                                reply
# 1835                                                reply
# Name: clean_tweet, Length: 1836, dtype: object

# %%
tweet_list_june
# Out:
# 0       notice change psychological physical condition...
# 1       goodbye indian south african british coronavir...
# 2                                     dear donate retweet
# 3                  best future dream job direct sell like
# 4       mosque worshiper visitor pray corona virus end...
#                               ...
# 2434                          covid impact family country
# 2435    entire govt machinery work resolute leadership...
# 2436            young life covid husband colleague mumbai
# 2437                                                reply
# 2438    effective vaccine protect family member countr...
# Name: clean_tweet, Length: 2439, dtype: object

# %%
tweet_list_july
# Out:
# 0                                     covid admission far
# 1                  uggah sarawak free covid delta variant
# 2                                  follow covid guideline
# 3       parent senior citizen vaccinate way port blair...
# 4       fastspreading delta variant vaccination rate r...
#                               ...
# 1988    double vaccine protect variant report afp news...
# 1989          covid vaccine havent vaccine love one world
# 1990                  salute real worrier covid   kolkata
# 1991    sir passenger fully vaccinate pcr formality be...
# 1992    warm wish doctor day doctor work hard restore ...
# Name: clean_tweet, Length: 1993, dtype: object

# %%
tweet_list_august
# Out:
# 0       treatment covid hydroquinone ivermectin zincov...
# 1       yes oxygen remdesivir versus hindumuslim agend...
# 2       pt remdesivir tociluzimab urgently wid icu bed...
# 3        citizen india request oxygen remdesivir remember
# 4                remdesivir india reach help flight covid
#                               ...
# 1693    thought thing normal end covid vaccine availab...
# 1694          covid vaccination pregnancy srishti clin...
# 1695    covid advisor new lockdown expect despite delt...
# 1696                  covid vaccine prioritize distribute
# 1697    update schedule announce withdrawn participate...
# Name: clean_tweet, Length: 1698, dtype: object

# %%
ps=PorterStemmer()

# %%
for i in range(0,march.shape[0]):
    ls=tweet_list_march[i]
    words = word_tokenize(ls)
    st=""
    for w in words:
        w=ps.stem(w)
        st+=w+' '
    tweet_list_march[i]=st
for i in range(0,march.shape[0]):
    ls=Convert_list(tweet_list_march[i])
    remove_single_char(ls)
    remove_dual_char(ls)
    ls=remove_words(ls,custom_words)
    tweet_list_march[i]=listToString(ls)
    
for i in range(0,april.shape[0]):
    ls=tweet_list_april[i]
    words = word_tokenize(ls)
    st=""
    for w in words:
        w=ps.stem(w)
        st+=w+' '
    tweet_list_april[i]=st
for i in range(0,april.shape[0]):
    ls=Convert_list(tweet_list_april[i])
    remove_single_char(ls)
    remove_dual_char(ls)
    ls=remove_words(ls,custom_words)
    tweet_list_april[i]=listToString(ls)
    
for i in range(0,may.shape[0]):
    ls=tweet_list_may[i]
    words = word_tokenize(ls)
    st=""
    for w in words:
        w=ps.stem(w)
        st+=w+' '
    tweet_list_may[i]=st
for i in range(0,may.shape[0]):
    ls=Convert_list(tweet_list_may[i])
    remove_single_char(ls)
    remove_dual_char(ls)
    ls=remove_words(ls,custom_words)
    tweet_list_may[i]=listToString(ls)
    
for i in range(0,june.shape[0]):
    ls=tweet_list_june[i]
    words = word_tokenize(ls)
    st=""
    for w in words:
        w=ps.stem(w)
        st+=w+' '
    tweet_list_june[i]=st
for i in range(0,june.shape[0]):
    ls=Convert_list(tweet_list_june[i])
    remove_single_char(ls)
    remove_dual_char(ls)
    ls=remove_words(ls,custom_words)
    tweet_list_june[i]=listToString(ls)
    
for i in range(0,july.shape[0]):
    ls=tweet_list_july[i]
    words = word_tokenize(ls)
    st=""
    for w in words:
        w=ps.stem(w)
        st+=w+' '
    tweet_list_july[i]=st
for i in range(0,july.shape[0]):
    ls=Convert_list(tweet_list_july[i])
    remove_single_char(ls)
    remove_dual_char(ls)
    ls=remove_words(ls,custom_words)
    tweet_list_july[i]=listToString(ls)
    
for i in range(0,august.shape[0]):
    ls=tweet_list_august[i]
    words = word_tokenize(ls)
    st=""
    for w in words:
        w=ps.stem(w)
        st+=w+' '
    tweet_list_august[i]=st
for i in range(0,august.shape[0]):
    ls=Convert_list(tweet_list_august[i])
    remove_single_char(ls)
    remove_dual_char(ls)
    ls=remove_words(ls,custom_words)
    tweet_list_august[i]=listToString(ls)

# %%
tweets_tokens_march= [token for line in tweet_list_march for token in line.split()]
tweets_tokens_april= [token for line in tweet_list_april for token in line.split()]
tweets_tokens_may= [token for line in tweet_list_may for token in line.split()]
tweets_tokens_june= [token for line in tweet_list_june for token in line.split()]
tweets_tokens_july= [token for line in tweet_list_july for token in line.split()]
tweets_tokens_august= [token for line in tweet_list_august for token in line.split()]

# %%
tweets_tokens_august
# Out:
# ['treatment',
#  'covid',
#  'hydroquinon',
#  'ivermectin',
#  'zincovit',
#  'celin',
#  'vitc',
#  'paracetamol',
#  'doxi',
#  'antibodi',
#  'cocktail',
#  'dexamethason',
#  'azithromycin',
#  'remdesivir',
#  'frapivir',
#  'oxygen',
#  'vaccin',
#  'prevent',
#  'oxygen',
#  'remdesivir',
#  'versu',
#  'hindumuslim',
#  'agenda',
#  'time',
#  'hospit',
#  'bed',
#  'versu',
#  'templ',
#  'polit',
#  'feed',
#  'peacock',
#  'versu',
#  'hungri',
#  'migrantsth',
#  'list',
#  'longveri',
#  'long',
#  'remdesivir',
#  'tociluzimab',
#  'urgent',
#  'wid',
#  'icu',
#  'bed',
#  'avail',
#  'kindli',
#  'help',
#  'kdmc',
#  'plz',
#  'contact',
#  'citizen',
#  'india',
#  'request',
#  'oxygen',
#  'remdesivir',
#  'rememb',
#  'remdesivir',
#  'india',
#  'reach',
#  'help',
#  'flight',
#  'covid',
#  'instead',
#  'manag',
#  'covid',
#  'tact',
#  'bjp',
#  'leader',
#  'involv',
#  'scam',
#  'relat',
#  'covid',
#  'relief',
#  'care',
#  'fund',
#  'scam',
# ...

# %%
def get_tweets_tokens(docx,num=100):
    num=len(docx)
    word_tokens = Counter(docx)
    most_common = word_tokens.most_common(num)
    result = dict(most_common)
    return result

# %%
most_common_words_march = get_tweets_tokens(tweets_tokens_march)
tweet_df_march = pd.DataFrame(most_common_words_march.items(),columns=['words','scores'])

most_common_words_april = get_tweets_tokens(tweets_tokens_april)
tweet_df_april = pd.DataFrame(most_common_words_april.items(),columns=['words','scores'])

most_common_words_may= get_tweets_tokens(tweets_tokens_may)
tweet_df_may= pd.DataFrame(most_common_words_may.items(),columns=['words','scores'])

most_common_words_june= get_tweets_tokens(tweets_tokens_june)
tweet_df_june = pd.DataFrame(most_common_words_june.items(),columns=['words','scores'])

most_common_words_july = get_tweets_tokens(tweets_tokens_july)
tweet_df_july = pd.DataFrame(most_common_words_july.items(),columns=['words','scores'])

most_common_words_august = get_tweets_tokens(tweets_tokens_august)
tweet_df_august = pd.DataFrame(most_common_words_august.items(),columns=['words','scores'])

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='words',y='scores',data=tweet_df_march[0:30]).set(title="March")
plt.xticks(rotation=45)

plt.figure(figsize=(20,10))
sns.barplot(x='words',y='scores',data=tweet_df_april[0:30]).set(title="April")
plt.xticks(rotation=45)

plt.figure(figsize=(20,10))
sns.barplot(x='words',y='scores',data=tweet_df_may[0:30]).set(title="May")
plt.xticks(rotation=45)

plt.figure(figsize=(20,10))
sns.barplot(x='words',y='scores',data=tweet_df_june[0:30]).set(title="June")
plt.xticks(rotation=45)

plt.figure(figsize=(20,10))
sns.barplot(x='words',y='scores',data=tweet_df_july[0:30]).set(title="July",)
plt.xticks(rotation=45)

plt.figure(figsize=(20,10))
sns.barplot(x='words',y='scores',data=tweet_df_august[0:30]).set(title="August")
plt.xticks(rotation=45)
plt.show()

# %%
tweet_df_march['words'][99]
# Out:
# 'delhi'

# %%
tweet_df_march['scores'][99]
# Out:
# 37

# %%
tweet_df_march.to_csv('MarchTopWords.csv')
tweet_df_april.to_csv('AprilTopWords.csv')
tweet_df_may.to_csv('MayTopWords.csv')
tweet_df_june.to_csv('JuneTopWords.csv')
tweet_df_july.to_csv('JulyTopWords.csv')
tweet_df_august.to_csv('AugustTopWords.csv')

# %%
df = tweet_df_march[:50]

#Checking the Data

df.head()

#Creating the text variable

text2 = " ".join(title for title in df.words)

# Creating word_cloud with text as argument in .generate() method

word_cloud2 = WordCloud(collocations = False, background_color = 'white').generate(text2)

# Display the generated Word Cloud

plt.imshow(word_cloud2, interpolation='bilinear')

plt.axis("off")

plt.show()

# %%
mask = np.array(Image.open('Twitter-PNG-Image.png'))
text2 = " ".join(title for title in df['words'])
wordcloud = WordCloud(width=1600, mask =   mask,height=800,max_font_size=200,max_words=50,collocations=False).generate(text2)
f = plt.figure(figsize=(50,50))
# f.add_subplot(1,2, 1)
# plt.imshow(mask, cmap=plt.cm.gray, interpolation='bilinear')
# plt.title('Original Image', size=40)
plt.axis("off")
# f.add_subplot(1,2, 2)
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Generated Word Cloud', size=40)
plt.axis("off")
plt.show()
