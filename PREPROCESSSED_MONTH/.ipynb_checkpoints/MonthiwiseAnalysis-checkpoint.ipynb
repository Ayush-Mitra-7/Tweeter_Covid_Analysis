# %%
import pandas as pd
import numpy as np
import math
from textblob import TextBlob as tb
import re
from nltk.corpus import stopwords
import neattext.functions as nfx
import emoji
import advertools as adv
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
from wordcloud import WordCloud
from PIL import Image
plt.style.use('ggplot')
import string

import gensim #the library for Topic modelling
from gensim.models.ldamulticore import LdaMulticore
from gensim import corpora, models
from nltk.stem.wordnet import WordNetLemmatizer
import pyLDAvis #LDA visualization library
import pyLDAvis.gensim_models
from gensim.corpora import Dictionary
from gensim.models.ldamodel import LdaModel
from gensim.models.coherencemodel import CoherenceModel

import warnings
warnings.simplefilter('ignore')
from itertools import chain

# %%
march=pd.read_csv('01_PREPROCESSED_MARCH.csv')
april=pd.read_csv('02_PREPROCESSED_APRIL.csv')
may=pd.read_csv('03_PREPROCESSED_MAY.csv')
june=pd.read_csv('04_PREPROCESSED_JUNE.csv')
july=pd.read_csv('05_PREPROCESSED_JULY.csv')
august=pd.read_csv('06_PREPROCESSED_AUGUST.csv')

# %%
march['tokenized_Tweet']=np.nan
april['tokenized_Tweet']=np.nan
may['tokenized_Tweet']=np.nan
june['tokenized_Tweet']=np.nan
july['tokenized_Tweet']=np.nan
august['tokenized_Tweet']=np.nan

# %%
def tokenizing_march(text,i=0):
    text=tb(text)
    token_text=text.words
    token_text
    march['tokenized_Tweet'][i]=token_text
def tokenizing_april(text,i=0):
    text=tb(text)
    token_text=text.words
    token_text
    april['tokenized_Tweet'][i]=token_text
def tokenizing_may(text,i=0):
    text=tb(text)
    token_text=text.words
    token_text
    may['tokenized_Tweet'][i]=token_text
def tokenizing_june(text,i=0):
    text=tb(text)
    token_text=text.words
    token_text
    june['tokenized_Tweet'][i]=token_text
def tokenizing_july(text,i=0):
    text=tb(text)
    token_text=text.words
    token_text
    july['tokenized_Tweet'][i]=token_text
def tokenizing_august(text,i=0):
    text=tb(text)
    token_text=text.words
    token_text
    august['tokenized_Tweet'][i]=token_text

# %%
tokenizing_march(march['clean_tweet'][0],0)

# %%
a=march.shape
b=april.shape
c=may.shape
d=june.shape
e=july.shape
f=august.shape
print(a,b,c,d,e,f)
# Out:
# (2452, 7) (2624, 7) (1836, 7) (2439, 7) (1993, 7) (1698, 7)

# %%
for i in range(0,2452):
    text=march['clean_tweet'][i]
    tokenizing_march(text,i)

# %%
march['tokenized_Tweet']
# Out:
# 0       [Germanys, Covid, response, was, the, envy, of...
# 1       [Pfizer, amp, Moderna, claim, their, vaccines,...
# 2       [We, recently, published, the, predictors, of,...
# 3       [Them, dey, do, Covid, test, 150AED, private, ...
# 4       [Time, will, tell, So, far, and, based, on, th...
#                               ...
# 2447    [If, you, guys, can, not, control, covid, 19, ...
# 2448    [In, Barasat, Hospital, COVID19, Vaccines, sho...
# 2449                                       [Replying, to]
# 2450    [Dear, sir, request, you, to, allow, the, vacc...
# 2451    [Dear, sir, request, you, to, allow, the, vacc...
# Name: tokenized_Tweet, Length: 2452, dtype: object

# %%
for i in range(0,2624):
    text=april['clean_tweet'][i]
    tokenizing_april(text,i)

# %%
for i in range(0,1836):
    text=may['clean_tweet'][i]
    tokenizing_may(text,i)

# %%
for i in range(0,2439):
    text=june['clean_tweet'][i]
    tokenizing_june(text,i)

# %%
for i in range(0,1993):
    text=july['clean_tweet'][i]
    tokenizing_july(text,i)

# %%
for i in range(0,1698):
    text=august['clean_tweet'][i]
    tokenizing_august(text,i)

# %%
august
# Out:
#                                                   tweet  \
# 0     Line of Treatment for Covid-19 Hydroquinone  I...
# 1     Yes, it's Oxygen and Remdesivir Versus Hindu-M...
# 2     @KDMCOfficial one of my pts needs remdesivir a...
# 3     So many citizens across India requested you fo...
# 4     Remdesivir “made in India” just reached #HoChi...
# ...                                                 ...
# 1693  I thought things would go back to normal by th...
# 1694    𝓣𝓸 𝓽𝓪𝓴𝓮 𝓸𝓻 𝓷𝓸𝓽 𝓽𝓸 𝓽𝓪𝓴𝓮 - the Covid  - 19 vac...
# 1695  US Top COVID-19 Advisor Says No New Lockdowns ...
# 1696  "How COVID-19 vaccines are being prioritized a...
# 1697  Updated schedule announced by \n@ICC\n , as \n...
#
#                                             clean_tweet  \
# 0     Line of Treatment for Covid19 Hydroquinone Ive...
# 1     Yes its Oxygen and Remdesivir Versus HinduMusl...
# 2      one of my pts needs remdesivir and tociluzima...
# 3     So many citizens across India requested you fo...
# ...

# %%
march['filteredToken']=np.nan
april['filteredToken']=np.nan
may['filteredToken']=np.nan
june['filteredToken']=np.nan
july['filteredToken']=np.nan
august['filteredToken']=np.nan

# %%
text_set=set(march['tokenized_Tweet'][0])
stop_set=set(stopwords.words("english"))
march['filteredToken'][0]=list(text_set-stop_set)

# %%
march['filteredToken'][0]
# Out:
# ['via',
#  'world',
#  'response',
#  'reminder',
#  'Covid',
#  'daily',
#  'Germanys',
#  'envy',
#  'people',
#  'white',
#  'means']

# %%
march.shape[0]
# Out:
# 2452

# %%
stop_set=set(stopwords.words("english"))
for i in range(0,march.shape[0]):
    text_set=set(march['tokenized_Tweet'][i])
    march['filteredToken'][i]=list(text_set-stop_set)#set difference operation

# %%
stop_set=set(stopwords.words("english"))
for i in range(0,april.shape[0]):
    text_set=set(april['tokenized_Tweet'][i])
    april['filteredToken'][i]=list(text_set-stop_set)#set difference operation

# %%
stop_set=set(stopwords.words("english"))
for i in range(0,may.shape[0]):
    text_set=set(may['tokenized_Tweet'][i])
    may['filteredToken'][i]=list(text_set-stop_set)#set difference operation

# %%
stop_set=set(stopwords.words("english"))
for i in range(0,june.shape[0]):
    text_set=set(june['tokenized_Tweet'][i])
    june['filteredToken'][i]=list(text_set-stop_set)#set difference operation

# %%
stop_set=set(stopwords.words("english"))
for i in range(0,july.shape[0]):
    text_set=set(july['tokenized_Tweet'][i])
    july['filteredToken'][i]=list(text_set-stop_set)#set difference operation

# %%
stop_set=set(stopwords.words("english"))
for i in range(0,august.shape[0]):
    text_set=set(august['tokenized_Tweet'][i])
    august['filteredToken'][i]=list(text_set-stop_set)#set difference operation

# %%
def get_sentiment(text):
    text = tb(text)
    sentiment_polarity = text.sentiment.polarity
    sentiment_subjectivity = text.sentiment.subjectivity
    if sentiment_polarity > 0:
        sentiment_label = 'Positive'
    elif sentiment_polarity < 0:
        sentiment_label = 'Negative'
    else:
        sentiment_label = 'Neutral'
    result = {'polarity':sentiment_polarity,
              'subjectivity':sentiment_subjectivity,
              'sentiment':sentiment_label}
    return result

# %%
get_sentiment(march['clean_tweet'][0])
# Out:
# {'polarity': 0.0, 'subjectivity': 0.0, 'sentiment': 'Neutral'}

# %%
march['sentiment_results'] = march['clean_tweet'].apply(get_sentiment)
april['sentiment_results'] = april['clean_tweet'].apply(get_sentiment)
may['sentiment_results'] = may['clean_tweet'].apply(get_sentiment)
june['sentiment_results'] = june['clean_tweet'].apply(get_sentiment)
july['sentiment_results'] = july['clean_tweet'].apply(get_sentiment)
august['sentiment_results'] = august['clean_tweet'].apply(get_sentiment)

# %%
march = march.join(pd.json_normalize(march['sentiment_results']))
april = april.join(pd.json_normalize(april['sentiment_results']))
may = may.join(pd.json_normalize(may['sentiment_results']))
june = june.join(pd.json_normalize(june['sentiment_results']))
july = july.join(pd.json_normalize(july['sentiment_results']))
august = august.join(pd.json_normalize(august['sentiment_results']))

# %%
tweets_march=march['clean_tweet']
tweets_april=april['clean_tweet']
tweets_may=may['clean_tweet']
tweets_june=june['clean_tweet']
tweets_july=july['clean_tweet']
tweets_august=august['clean_tweet']

# %%
tweet_list_march = tweets_march.apply(nfx.remove_stopwords).tolist()
tweets_tokens_march= [token for line in tweet_list_march for token in line.split()]

tweet_list_april = tweets_april.apply(nfx.remove_stopwords).tolist()
tweets_tokens_april= [token for line in tweet_list_april for token in line.split()]

tweet_list_may = tweets_may.apply(nfx.remove_stopwords).tolist()
tweets_tokens_may= [token for line in tweet_list_may for token in line.split()]

tweet_list_june = tweets_june.apply(nfx.remove_stopwords).tolist()
tweets_tokens_june= [token for line in tweet_list_june for token in line.split()]

tweet_list_july = tweets_july.apply(nfx.remove_stopwords).tolist()
tweets_tokens_july= [token for line in tweet_list_july for token in line.split()]

tweet_list_august = tweets_august.apply(nfx.remove_stopwords).tolist()
tweets_tokens_august= [token for line in tweet_list_august for token in line.split()]

# %%
def get_tweets_tokens(docx,num=30):
    word_tokens = Counter(docx)
    most_common = word_tokens.most_common(num)
    result = dict(most_common)
    return result

# %%
most_common_words_march = get_tweets_tokens(tweets_tokens_march)
tweet_df_march = pd.DataFrame(most_common_words_march.items(),columns=['words','scores'])

most_common_words_april = get_tweets_tokens(tweets_tokens_april)
tweet_df_april = pd.DataFrame(most_common_words_april.items(),columns=['words','scores'])

most_common_words_may= get_tweets_tokens(tweets_tokens_may)
tweet_df_may= pd.DataFrame(most_common_words_may.items(),columns=['words','scores'])

most_common_words_june= get_tweets_tokens(tweets_tokens_june)
tweet_df_june = pd.DataFrame(most_common_words_june.items(),columns=['words','scores'])

most_common_words_july = get_tweets_tokens(tweets_tokens_july)
tweet_df_july = pd.DataFrame(most_common_words_july.items(),columns=['words','scores'])

most_common_words_august = get_tweets_tokens(tweets_tokens_august)
tweet_df_august = pd.DataFrame(most_common_words_august.items(),columns=['words','scores'])

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='words',y='scores',data=tweet_df_march).set(title="March")
plt.xticks(rotation=45)

plt.figure(figsize=(20,10))
sns.barplot(x='words',y='scores',data=tweet_df_april).set(title="April")
plt.xticks(rotation=45)

plt.figure(figsize=(20,10))
sns.barplot(x='words',y='scores',data=tweet_df_may).set(title="May")
plt.xticks(rotation=45)

plt.figure(figsize=(20,10))
sns.barplot(x='words',y='scores',data=tweet_df_june).set(title="June")
plt.xticks(rotation=45)

plt.figure(figsize=(20,10))
sns.barplot(x='words',y='scores',data=tweet_df_july).set(title="July")
plt.xticks(rotation=45)

plt.figure(figsize=(20,10))
sns.barplot(x='words',y='scores',data=tweet_df_august).set(title="August")
plt.xticks(rotation=45)
plt.show()

# %%
march['sentiment'].value_counts()
# Out:
# Positive    1199
# Neutral      817
# Negative     436
# Name: sentiment, dtype: int64

# %%
list=[]
Positive_Count=[]
Negative_Count=[]
Neutral_Count=[]

# %%
list=march['sentiment'].value_counts()
Positive_Count.append(list[0])
Negative_Count.append(list[2])
Neutral_Count.append(list[1])

# %%
Positive_Count
# Out:
# [1199]

# %%
Neutral_Count
# Out:
# [817]

# %%
Negative_Count
# Out:
# [436]

# %%
april['sentiment'].value_counts()
# Out:
# Positive    1115
# Neutral      949
# Negative     560
# Name: sentiment, dtype: int64

# %%
list=april['sentiment'].value_counts()
Positive_Count.append(list[0])
Negative_Count.append(list[2])
Neutral_Count.append(list[1])

# %%
a=Positive_Count
b=Neutral_Count
c=Negative_Count
print(a,b,c)
# Out:
# [1199, 1115] [817, 949] [436, 560]

# %%
may['sentiment'].value_counts()
# Out:
# Positive    813
# Neutral     680
# Negative    343
# Name: sentiment, dtype: int64

# %%
list=may['sentiment'].value_counts()
Positive_Count.append(list[0])
Negative_Count.append(list[2])
Neutral_Count.append(list[1])

# %%
a=Positive_Count
b=Neutral_Count
c=Negative_Count
print(a,b,c)
# Out:
# [1199, 1115, 813] [817, 949, 680] [436, 560, 343]

# %%
june['sentiment'].value_counts()
# Out:
# Positive    1129
# Neutral      842
# Negative     468
# Name: sentiment, dtype: int64

# %%
list=june['sentiment'].value_counts()
Positive_Count.append(list[0])
Negative_Count.append(list[2])
Neutral_Count.append(list[1])

# %%
july['sentiment'].value_counts()
# Out:
# Positive    879
# Neutral     693
# Negative    421
# Name: sentiment, dtype: int64

# %%
list=july['sentiment'].value_counts()
Positive_Count.append(list[0])
Negative_Count.append(list[2])
Neutral_Count.append(list[1])

# %%
august['sentiment'].value_counts()
# Out:
# Positive    776
# Neutral     583
# Negative    339
# Name: sentiment, dtype: int64

# %%
list=august['sentiment'].value_counts()
Positive_Count.append(list[0])
Negative_Count.append(list[2])
Neutral_Count.append(list[1])

# %%
a=Positive_Count
b=Neutral_Count
c=Negative_Count
print(a,b,c)
# Out:
# [1199, 1115, 813, 1129, 879, 776] [817, 949, 680, 842, 693, 583] [436, 560, 343, 468, 421, 339]

# %%
sentiment_dict=dict(Pos=Positive_Count,Neg=Negative_Count,Neu=Neutral_Count)

# %%
sentiment_data=pd.DataFrame(sentiment_dict)

# %%
month=['March','April',"May",'June','July','August']

# %%
plt.figure(figsize=(20,10))
plt.plot(month,Positive_Count,color='green')
plt.plot(month,Negative_Count,color='red')
plt.plot(month,Neutral_Count,color='blue')
plt.legend(["Postive Tweets","Negative Tweets","Neutral Tweets"])

plt.show()
# Out:
# 2022-03-28 01:51:50,218 | INFO | category.py:218 | update | Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2022-03-28 01:51:50,219 | INFO | category.py:218 | update | Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2022-03-28 01:51:50,221 | INFO | category.py:218 | update | Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ...

# %%
march.head(4)
# Out:
#                                                tweet  \
# 0  Germany's Covid response "was the envy of the ...
# 1  Pfizer &amp; Moderna claim their vaccines very...
# 2  We recently published the predictors of hospit...
# 3  @Alhamdhulillaah Them dey do Covid test 150AED...
#
#                                          clean_tweet  \
# 0  Germanys Covid response was the envy of the wo...
# 1  Pfizer amp Moderna claim their vaccines very s...
# 2  We recently published the predictors of hospit...
# 3   Them dey do Covid test 150AED private clinics...
#
#                                              hastags             attherate  \
# 0                                                 []       ['@GoogleNews']
# 1                                                 []                    []
# 2  ['#COVID19', '#CoronaVirusUpdates', '#geriatri...                    []
# 3                                                 []  ['@Alhamdhulillaah']
#
# ...

# %%
stop = set(stopwords.words('english'))
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()

def clean(text):
    stop_free = ' '.join([word for word in text.lower().split() if word not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = ' '.join([lemma.lemmatize(word) for word in punc_free.split()])
    return normalized.split()

# %%
march['filteredToken']=march['clean_tweet'].apply(clean)
april['filteredToken']=april['clean_tweet'].apply(clean)
may['filteredToken']=may['clean_tweet'].apply(clean)
june['filteredToken']=june['clean_tweet'].apply(clean)
july['filteredToken']=july['clean_tweet'].apply(clean)
august['filteredToken']=august['clean_tweet'].apply(clean)

# %%
march[['clean_tweet','filteredToken']]
# Out:
#                                             clean_tweet  \
# 0     Germanys Covid response was the envy of the wo...
# 1     Pfizer amp Moderna claim their vaccines very s...
# 2     We recently published the predictors of hospit...
# 3      Them dey do Covid test 150AED private clinics...
# 4      Time will tell So far and based on the data f...
# ...                                                 ...
# 2447   If you guys cannot control covid 19 in your s...
# 2448   In Barasat Hospital COVID19 Vaccines should b...
# 2449                                       Replying to
# 2450   Dear sir request you to allow the vaccination...
# 2451   Dear sir request you to allow the vaccination...
#
#                                           filteredToken
# 0     [germany, covid, response, envy, world, daily,...
# 1     [pfizer, amp, moderna, claim, vaccine, safe, a...
# 2     [recently, published, predictor, hospitalizati...
# 3     [dey, covid, test, 150aed, private, clinic, go...
# ...

# %%
all_words_march = [word for tokens in march['filteredToken']for word in tokens]
tweet_lengths_march = [len(tokens) for tokens in march['filteredToken']]

all_words_april = [word for tokens in april['filteredToken']for word in tokens]
tweet_lengths_april = [len(tokens) for tokens in april['filteredToken']]

all_words_may = [word for tokens in may['filteredToken']for word in tokens]
tweet_lengths_may = [len(tokens) for tokens in may['filteredToken']]

all_words_june = [word for tokens in june['filteredToken']for word in tokens]
tweet_lengths_june = [len(tokens) for tokens in june['filteredToken']]

all_words_july = [word for tokens in july['filteredToken']for word in tokens]
tweet_lengths_july = [len(tokens) for tokens in july['filteredToken']]

all_words_august = [word for tokens in august['filteredToken']for word in tokens]
tweet_lengths_august = [len(tokens) for tokens in august['filteredToken']]

# %%
plt.figure(figsize = (15,8))
sns.countplot(tweet_lengths_march)
plt.title('Tweet Length Distribution March', fontsize = 18)
plt.xlabel('Words per Tweet', fontsize = 12)
plt.ylabel('Number of Tweets', fontsize = 12)
plt.show()

plt.figure(figsize = (15,8))
sns.countplot(tweet_lengths_april)
plt.title('Tweet Length Distribution April', fontsize = 18)
plt.xlabel('Words per Tweet', fontsize = 12)
plt.ylabel('Number of Tweets', fontsize = 12)
plt.show()

plt.figure(figsize = (15,8))
sns.countplot(tweet_lengths_may)
plt.title('Tweet Length Distribution May', fontsize = 18)
plt.xlabel('Words per Tweet', fontsize = 12)
plt.ylabel('Number of Tweets', fontsize = 12)
plt.show()

plt.figure(figsize = (15,8))
sns.countplot(tweet_lengths_june)
plt.title('Tweet Length Distribution June', fontsize = 18)
plt.xlabel('Words per Tweet', fontsize = 12)
plt.ylabel('Number of Tweets', fontsize = 12)
plt.show()

plt.figure(figsize = (15,8))
sns.countplot(tweet_lengths_july)
plt.title('Tweet Length Distribution July', fontsize = 18)
plt.xlabel('Words per Tweet', fontsize = 12)
plt.ylabel('Number of Tweets', fontsize = 12)
plt.show()

plt.figure(figsize = (15,8))
sns.countplot(tweet_lengths_august)
plt.title('Tweet Length Distribution August', fontsize = 18)
plt.xlabel('Words per Tweet', fontsize = 12)
plt.ylabel('Number of Tweets', fontsize = 12)
plt.show()

# %%
#create dictionary
dictionary = corpora.Dictionary(march['filteredToken'])
#Total number of non-zeroes in the BOW matrix (sum of the number of unique words per document over the entire corpus).
print(dictionary.num_nnz)
# Out:
# 2022-03-28 01:51:54,222 | INFO | dictionary.py:199 | add_documents | adding document #0 to Dictionary(0 unique tokens: [])
# 2022-03-28 01:51:54,260 | INFO | dictionary.py:204 | add_documents | built Dictionary(7262 unique tokens: ['covid', 'daily', 'envy', 'germany', 'mean']...) from 2452 documents (total 36077 corpus positions)
# 2022-03-28 01:51:54,261 | INFO | utils.py:447 | add_lifecycle_event | Dictionary lifecycle event {'msg': "built Dictionary(7262 unique tokens: ['covid', 'daily', 'envy', 'germany', 'mean']...) from 2452 documents (total 36077 corpus positions)", 'datetime': '2022-03-28T01:51:54.261088', 'gensim': '4.1.2', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'created'}
# 33797

# %%
#create document term matrix
doc_term_matrix = [dictionary.doc2bow(doc) for doc in march['filteredToken']]
print(len(doc_term_matrix))
# Out:
# 2452

# %%
lda = gensim.models.ldamodel.LdaModel

# %%
num_topics=5
ldamodel = lda(doc_term_matrix,num_topics=num_topics,id2word=dictionary,passes=50,minimum_probability=0)
# Out:
# 2022-03-28 01:51:54,316 | INFO | ldamodel.py:576 | init_dir_prior | using symmetric alpha at 0.2
# 2022-03-28 01:51:54,317 | INFO | ldamodel.py:576 | init_dir_prior | using symmetric eta at 0.2
# 2022-03-28 01:51:54,318 | INFO | ldamodel.py:481 | __init__ | using serial LDA version on this node
# 2022-03-28 01:51:54,321 | INFO | ldamodel.py:947 | update | running online (multi-pass) LDA training, 5 topics, 50 passes over the supplied corpus of 2452 documents, updating model once every 2000 documents, evaluating perplexity every 2452 documents, iterating 50x with a convergence threshold of 0.001000
# 2022-03-28 01:51:54,322 | INFO | ldamodel.py:1001 | update | PROGRESS: pass 0, at document #2000/2452
# 2022-03-28 01:51:54,955 | INFO | ldamodel.py:233 | blend | merging changes from 2000 documents into a model of 2452 documents
# ...

# %%
ldamodel.print_topics(num_topics=num_topics)
# Out:
# 2022-03-28 01:52:12,912 | INFO | ldamodel.py:1196 | show_topics | topic #0 (0.200): 0.038*"case" + 0.018*"new" + 0.017*"death" + 0.016*"covid19" + 0.012*"total" + 0.011*"recovery" + 0.011*"coronavirus" + 0.010*"covid" + 0.010*"report" + 0.008*"india"
# 2022-03-28 01:52:12,913 | INFO | ldamodel.py:1196 | show_topics | topic #1 (0.200): 0.017*"covid19" + 0.017*"curfew" + 0.014*"corona" + 0.011*"virus" + 0.011*"mask" + 0.010*"pm" + 0.010*"night" + 0.009*"people" + 0.009*"hand" + 0.008*"due"
# 2022-03-28 01:52:12,913 | INFO | ldamodel.py:1196 | show_topics | topic #2 (0.200): 0.010*"covid" + 0.009*"covid19" + 0.009*"curfew" + 0.008*"one" + 0.007*"u" + 0.006*"amp" + 0.006*"mr" + 0.005*"news" + 0.005*"corona" + 0.004*"people"
# 2022-03-28 01:52:12,914 | INFO | ldamodel.py:1196 | show_topics | topic #3 (0.200): 0.018*"covid" + 0.012*"curfew" + 0.010*"corona" + 0.010*"lockdown" + 0.009*"19" + 0.009*"coronavirus" + 0.008*"people" + 0.007*"virus" + 0.007*"covid19" + 0.006*"amp"
# ...

# %%
lda_display = pyLDAvis.gensim_models.prepare(ldamodel, doc_term_matrix, dictionary, sort_topics=False, mds='mmds')
pyLDAvis.display(lda_display)
# Out:
# 2022-03-28 01:52:13,174 | INFO | utils.py:157 | _init_num_threads | NumExpr defaulting to 8 threads.
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el2308020772884031206117041033"></div>
# <script type="text/javascript">
#
# ...

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.ldamodel.LdaModel(corpus=corpus, num_topics=num_topics, id2word=dictionary)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
model_list, coherence_values = compute_coherence_values(dictionary=dictionary, corpus=doc_term_matrix, texts=march['filteredToken'], limit=50, start=2, step=3)
# Out:
# 2022-03-28 01:52:15,846 | INFO | ldamodel.py:576 | init_dir_prior | using symmetric alpha at 0.5
# 2022-03-28 01:52:15,847 | INFO | ldamodel.py:576 | init_dir_prior | using symmetric eta at 0.5
# 2022-03-28 01:52:15,848 | INFO | ldamodel.py:481 | __init__ | using serial LDA version on this node
# 2022-03-28 01:52:15,851 | INFO | ldamodel.py:947 | update | running online (single-pass) LDA training, 2 topics, 1 passes over the supplied corpus of 2452 documents, updating model once every 2000 documents, evaluating perplexity every 2452 documents, iterating 50x with a convergence threshold of 0.001000
# 2022-03-28 01:52:15,851 | WARNING | ldamodel.py:958 | update | too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2022-03-28 01:52:15,852 | INFO | ldamodel.py:1001 | update | PROGRESS: pass 0, at document #2000/2452
# ...

# %%
limit=50; start=2; step=1;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()# Print the coherence scores

# %%
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))

# %%
optimal_model = model_list[46]
model_topics = optimal_model.show_topics(formatted=False)
optimal_model.print_topics(num_words=10)

# %%
lda_display = pyLDAvis.gensim_models.prepare(optimal_model, doc_term_matrix, dictionary, sort_topics=False, mds='mmds')
pyLDAvis.display(lda_display)

# %%
def format_topics_sentences(ldamodel=None, corpus=doc_term_matrix, texts=march['filteredToken']):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model, corpus=doc_term_matrix, texts=march['filteredToken'])

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head(10)
